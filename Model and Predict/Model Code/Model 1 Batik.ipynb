# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop

# %%
train_path = os.path.join('./data/DATASETv7/TRAIN')
val_path = os.path.join('./data/DATASETv7/TEST')
img_size = 150
batch_size = 64

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    rotation_range = 10,
    zoom_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
)

val_datagen = ImageDataGenerator(
    rescale = 1./255,
)

train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size = (img_size, img_size),
    batch_size = batch_size,
    class_mode = 'sparse',
)

val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size = (img_size, img_size),
    batch_size = batch_size,
    class_mode = 'sparse',
)
# Out:
# Found 1050 images belonging to 15 classes.
# Found 300 images belonging to 15 classes.

# %%
model = tf.keras.models.Sequential([
    # This is the first convolution
    tf.keras.layers.Conv2D(32, (3,3), padding = 'same', activation='relu', input_shape=(img_size, img_size, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    # The second convolution
    tf.keras.layers.Conv2D(64, (3,3), padding = 'same', activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
#     tf.keras.layers.Dropout(0.5),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(64, activation='relu'),
    # Only 1 output neuron. It will contain a value from 0-1 where 0 for 1 class ('horses') and 1 for the other ('humans')
    tf.keras.layers.Dense(15, activation='softmax')
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 87616)             0
#
#  dense (Dense)               (None, 64)                5607488
#
#  dense_1 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 5,627,855
# Trainable params: 5,627,855
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set the training parameters
model.compile(loss = 'sparse_categorical_crossentropy', 
              optimizer = Adam(), 
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(train_generator, 
                    epochs=100, 
                    validation_data = val_generator)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.6496 - accuracy: 0.4762 - val_loss: 2.5072 - val_accuracy: 0.3033
# Epoch 2/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.6727 - accuracy: 0.4762 - val_loss: 2.5005 - val_accuracy: 0.3067
# Epoch 3/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.6697 - accuracy: 0.4667 - val_loss: 2.4868 - val_accuracy: 0.3300
# Epoch 4/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.5843 - accuracy: 0.5010 - val_loss: 2.6309 - val_accuracy: 0.3000
# Epoch 5/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.5267 - accuracy: 0.5067 - val_loss: 2.4930 - val_accuracy: 0.3300
# Epoch 6/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.4759 - accuracy: 0.5181 - val_loss: 2.5101 - val_accuracy: 0.3433
# Epoch 7/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.5086 - accuracy: 0.5181 - val_loss: 2.7229 - val_accuracy: 0.2700
# Epoch 8/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.4911 - accuracy: 0.5390 - val_loss: 2.3755 - val_accuracy: 0.3533
# Epoch 9/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.4423 - accuracy: 0.5562 - val_loss: 2.6221 - val_accuracy: 0.3400
# Epoch 10/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.3868 - accuracy: 0.5571 - val_loss: 2.6175 - val_accuracy: 0.3167
# Epoch 11/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.3505 - accuracy: 0.5610 - val_loss: 2.5376 - val_accuracy: 0.3500
# Epoch 12/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.3380 - accuracy: 0.5629 - val_loss: 2.7902 - val_accuracy: 0.3167
# Epoch 13/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.3093 - accuracy: 0.5838 - val_loss: 2.8819 - val_accuracy: 0.3200
# Epoch 14/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.3023 - accuracy: 0.5876 - val_loss: 2.5317 - val_accuracy: 0.3133
# Epoch 15/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.2412 - accuracy: 0.6171 - val_loss: 2.8934 - val_accuracy: 0.3067
# Epoch 16/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.2735 - accuracy: 0.5971 - val_loss: 2.7971 - val_accuracy: 0.3167
# Epoch 17/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.2147 - accuracy: 0.6105 - val_loss: 2.7545 - val_accuracy: 0.3033
# Epoch 18/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.1599 - accuracy: 0.6410 - val_loss: 2.7759 - val_accuracy: 0.2967
# Epoch 19/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.1104 - accuracy: 0.6429 - val_loss: 3.0289 - val_accuracy: 0.3167
# Epoch 20/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.0937 - accuracy: 0.6648 - val_loss: 2.9220 - val_accuracy: 0.3267
# Epoch 21/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.0575 - accuracy: 0.6600 - val_loss: 2.8169 - val_accuracy: 0.3233
# Epoch 22/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.1608 - accuracy: 0.6352 - val_loss: 2.6219 - val_accuracy: 0.3400
# Epoch 23/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.1204 - accuracy: 0.6610 - val_loss: 2.8147 - val_accuracy: 0.3033
# Epoch 24/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.0896 - accuracy: 0.6438 - val_loss: 2.9173 - val_accuracy: 0.3167
# Epoch 25/100
# 17/17 [==============================] - 19s 1s/step - loss: 1.0664 - accuracy: 0.6600 - val_loss: 2.7376 - val_accuracy: 0.2900
# Epoch 26/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.0317 - accuracy: 0.6638 - val_loss: 2.9862 - val_accuracy: 0.3300
# Epoch 27/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.0523 - accuracy: 0.6705 - val_loss: 2.9074 - val_accuracy: 0.3133
# Epoch 28/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.0423 - accuracy: 0.6714 - val_loss: 2.7934 - val_accuracy: 0.3300
# Epoch 29/100
# 17/17 [==============================] - 17s 1s/step - loss: 1.0279 - accuracy: 0.6657 - val_loss: 2.7565 - val_accuracy: 0.3500
# Epoch 30/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.9675 - accuracy: 0.6876 - val_loss: 3.0971 - val_accuracy: 0.3200
# Epoch 31/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.8974 - accuracy: 0.7210 - val_loss: 3.0388 - val_accuracy: 0.3300
# Epoch 32/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.8723 - accuracy: 0.7133 - val_loss: 2.8920 - val_accuracy: 0.3433
# Epoch 33/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.9161 - accuracy: 0.7038 - val_loss: 3.1569 - val_accuracy: 0.3133
# Epoch 34/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.8293 - accuracy: 0.7352 - val_loss: 3.1934 - val_accuracy: 0.3433
# Epoch 35/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.8136 - accuracy: 0.7305 - val_loss: 3.2592 - val_accuracy: 0.3033
# Epoch 36/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.8245 - accuracy: 0.7362 - val_loss: 3.1000 - val_accuracy: 0.3333
# Epoch 37/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7519 - accuracy: 0.7619 - val_loss: 3.3203 - val_accuracy: 0.3400
# Epoch 38/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.8200 - accuracy: 0.7381 - val_loss: 3.3559 - val_accuracy: 0.3267
# Epoch 39/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7948 - accuracy: 0.7505 - val_loss: 3.4584 - val_accuracy: 0.3233
# Epoch 40/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.6919 - accuracy: 0.7810 - val_loss: 3.6794 - val_accuracy: 0.3000
# Epoch 41/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7641 - accuracy: 0.7381 - val_loss: 3.6474 - val_accuracy: 0.3267
# Epoch 42/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7664 - accuracy: 0.7514 - val_loss: 3.1706 - val_accuracy: 0.3433
# Epoch 43/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7061 - accuracy: 0.7838 - val_loss: 3.3459 - val_accuracy: 0.3467
# Epoch 44/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.6853 - accuracy: 0.7743 - val_loss: 3.4483 - val_accuracy: 0.3267
# Epoch 45/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7128 - accuracy: 0.7743 - val_loss: 3.4230 - val_accuracy: 0.2933
# Epoch 46/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.6904 - accuracy: 0.7790 - val_loss: 3.9294 - val_accuracy: 0.2933
# Epoch 47/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7031 - accuracy: 0.7733 - val_loss: 3.7160 - val_accuracy: 0.3267
# Epoch 48/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7268 - accuracy: 0.7638 - val_loss: 3.4489 - val_accuracy: 0.3233
# Epoch 49/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7376 - accuracy: 0.7629 - val_loss: 3.2647 - val_accuracy: 0.3433
# Epoch 50/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.7066 - accuracy: 0.7733 - val_loss: 3.8376 - val_accuracy: 0.3133
# Epoch 51/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.6946 - accuracy: 0.7686 - val_loss: 3.5758 - val_accuracy: 0.3267
# Epoch 52/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7071 - accuracy: 0.7667 - val_loss: 3.8133 - val_accuracy: 0.2967
# Epoch 53/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.6313 - accuracy: 0.7943 - val_loss: 3.6704 - val_accuracy: 0.3600
# Epoch 54/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.6118 - accuracy: 0.8095 - val_loss: 3.9540 - val_accuracy: 0.3167
# Epoch 55/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.6176 - accuracy: 0.7943 - val_loss: 3.5863 - val_accuracy: 0.3633
# Epoch 56/100
# 17/17 [==============================] - 17s 997ms/step - loss: 0.5710 - accuracy: 0.8267 - val_loss: 3.9083 - val_accuracy: 0.3600
# Epoch 57/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.5207 - accuracy: 0.8324 - val_loss: 3.8254 - val_accuracy: 0.3333
# Epoch 58/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.5282 - accuracy: 0.8257 - val_loss: 3.8443 - val_accuracy: 0.3367
# Epoch 59/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.5237 - accuracy: 0.8314 - val_loss: 3.9514 - val_accuracy: 0.3233
# Epoch 60/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.5318 - accuracy: 0.8400 - val_loss: 4.0496 - val_accuracy: 0.3400
# Epoch 61/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.5616 - accuracy: 0.8400 - val_loss: 4.1577 - val_accuracy: 0.3500
# Epoch 62/100
# 17/17 [==============================] - 17s 998ms/step - loss: 0.5506 - accuracy: 0.8219 - val_loss: 4.0094 - val_accuracy: 0.3300
# Epoch 63/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.5018 - accuracy: 0.8381 - val_loss: 3.8316 - val_accuracy: 0.3633
# Epoch 64/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.4986 - accuracy: 0.8438 - val_loss: 4.5488 - val_accuracy: 0.3233
# Epoch 65/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.5398 - accuracy: 0.8276 - val_loss: 4.1092 - val_accuracy: 0.3500
# Epoch 66/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.5120 - accuracy: 0.8438 - val_loss: 3.9763 - val_accuracy: 0.3533
# Epoch 67/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.4556 - accuracy: 0.8581 - val_loss: 4.1595 - val_accuracy: 0.3800
# Epoch 68/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.4682 - accuracy: 0.8400 - val_loss: 4.2658 - val_accuracy: 0.3667
# Epoch 69/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.4616 - accuracy: 0.8562 - val_loss: 4.1490 - val_accuracy: 0.3533
# Epoch 70/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.4524 - accuracy: 0.8495 - val_loss: 4.0794 - val_accuracy: 0.3567
# Epoch 71/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.4813 - accuracy: 0.8429 - val_loss: 4.0758 - val_accuracy: 0.3500
# Epoch 72/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.4133 - accuracy: 0.8724 - val_loss: 4.1171 - val_accuracy: 0.3533
# Epoch 73/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.4318 - accuracy: 0.8648 - val_loss: 4.4587 - val_accuracy: 0.3233
# Epoch 74/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.4530 - accuracy: 0.8581 - val_loss: 4.3282 - val_accuracy: 0.3433
# Epoch 75/100
# 17/17 [==============================] - 17s 998ms/step - loss: 0.4220 - accuracy: 0.8686 - val_loss: 4.4256 - val_accuracy: 0.3600
# Epoch 76/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.4684 - accuracy: 0.8467 - val_loss: 3.9311 - val_accuracy: 0.3400
# Epoch 77/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.4207 - accuracy: 0.8676 - val_loss: 4.4135 - val_accuracy: 0.3100
# Epoch 78/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.4449 - accuracy: 0.8467 - val_loss: 4.3976 - val_accuracy: 0.3400
# Epoch 79/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.3763 - accuracy: 0.8867 - val_loss: 4.8453 - val_accuracy: 0.3333
# Epoch 80/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.3827 - accuracy: 0.8733 - val_loss: 4.2635 - val_accuracy: 0.3567
# Epoch 81/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.4202 - accuracy: 0.8657 - val_loss: 4.3010 - val_accuracy: 0.3600
# Epoch 82/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.4144 - accuracy: 0.8762 - val_loss: 4.7026 - val_accuracy: 0.3633
# Epoch 83/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.4792 - accuracy: 0.8505 - val_loss: 4.6164 - val_accuracy: 0.3133
# Epoch 84/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.3880 - accuracy: 0.8819 - val_loss: 4.4052 - val_accuracy: 0.3667
# Epoch 85/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.3699 - accuracy: 0.8895 - val_loss: 4.5216 - val_accuracy: 0.3767
# Epoch 86/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.3312 - accuracy: 0.9038 - val_loss: 4.6690 - val_accuracy: 0.3467
# Epoch 87/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.3491 - accuracy: 0.8981 - val_loss: 4.4834 - val_accuracy: 0.3600
# Epoch 88/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.3376 - accuracy: 0.9029 - val_loss: 4.7258 - val_accuracy: 0.3367
# Epoch 89/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.3261 - accuracy: 0.8952 - val_loss: 4.6316 - val_accuracy: 0.3433
# Epoch 90/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.2967 - accuracy: 0.9038 - val_loss: 5.2076 - val_accuracy: 0.3300
# Epoch 91/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.3419 - accuracy: 0.8867 - val_loss: 5.2182 - val_accuracy: 0.3533
# Epoch 92/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.3599 - accuracy: 0.8981 - val_loss: 5.2486 - val_accuracy: 0.3400
# Epoch 93/100
# 17/17 [==============================] - 10814s 676s/step - loss: 0.3104 - accuracy: 0.9076 - val_loss: 5.1898 - val_accuracy: 0.3300
# Epoch 94/100
# 17/17 [==============================] - 1269s 866ms/step - loss: 0.2631 - accuracy: 0.9210 - val_loss: 4.9795 - val_accuracy: 0.3633
# Epoch 95/100
# 17/17 [==============================] - 13s 762ms/step - loss: 0.3136 - accuracy: 0.9076 - val_loss: 4.8497 - val_accuracy: 0.3400
# Epoch 96/100
# 17/17 [==============================] - 13s 768ms/step - loss: 0.3257 - accuracy: 0.8924 - val_loss: 5.0079 - val_accuracy: 0.3567
# Epoch 97/100
# 17/17 [==============================] - 13s 762ms/step - loss: 0.3053 - accuracy: 0.9000 - val_loss: 5.0444 - val_accuracy: 0.3567
# Epoch 98/100
# 17/17 [==============================] - 13s 757ms/step - loss: 0.2976 - accuracy: 0.9067 - val_loss: 5.5330 - val_accuracy: 0.3600
# Epoch 99/100
# 17/17 [==============================] - 13s 733ms/step - loss: 0.2981 - accuracy: 0.9086 - val_loss: 5.4736 - val_accuracy: 0.3133
# Epoch 100/100
# 17/17 [==============================] - 14s 789ms/step - loss: 0.3298 - accuracy: 0.8933 - val_loss: 5.4792 - val_accuracy: 0.3500
